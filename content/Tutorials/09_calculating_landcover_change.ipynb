# %% [markdown]
# # 05. Calculating landcover change over time

# %% [markdown]
# ## imports

# %%
import leafmap
import leafmap.colormaps as cm
import requests
import rasterio as rio
from rasterio.merge import merge
import glob
from rasterio.plot import reshape_as_image
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %% [markdown]
# ## searching for data

# %%
url = "https://earth-search.aws.element84.com/v1/"
collection = "sentinel-2-l2a"
time_range = "2023-08-01/2023-08-31"

# %%
# bbox for dallas metro
bbox = [
    -97.06213756027009,
    32.97324551867027,
    -96.46807822577594,
    33.3578329610085,
]

# %%
search_gdf = leafmap.stac_search(
    url=url,
    max_items=10,
    collections=[collection],
    bbox=bbox,
    datetime=time_range,
    query={"eo:cloud_cover": {"lt": 20}},
    sortby=[{"field": "properties.eo:cloud_cover", "direction": "asc"}],
    get_gdf=True,
)

# %%
search_gdf.columns
# Out:
# Index(['geometry', 'created', 'platform', 'constellation', 'instruments',
#        'eo:cloud_cover', 'mgrs:utm_zone', 'mgrs:latitude_band',
#        'mgrs:grid_square', 'grid:code', 'view:sun_azimuth',
#        'view:sun_elevation', 's2:degraded_msi_data_percentage',
#        's2:nodata_pixel_percentage', 's2:saturated_defective_pixel_percentage',
#        's2:dark_features_percentage', 's2:cloud_shadow_percentage',
#        's2:vegetation_percentage', 's2:not_vegetated_percentage',
#        's2:water_percentage', 's2:unclassified_percentage',
#        's2:medium_proba_clouds_percentage', 's2:high_proba_clouds_percentage',
#        's2:thin_cirrus_percentage', 's2:snow_ice_percentage',
#        's2:product_type', 's2:processing_baseline', 's2:product_uri',
#        's2:generation_time', 's2:datatake_id', 's2:datatake_type',
#        's2:datastrip_id', 's2:granule_id', 's2:reflectance_conversion_factor',
#        'datetime', 's2:sequence', 'earthsearch:s3_path',
#        'earthsearch:payload_id', 'earthsearch:boa_offset_applied',
#        'processing:software', 'updated', 'proj:code'],
#       dtype='str')

# %%
search_gdf
# Out:
#                                             geometry  \
# 0  POLYGON ((-96.84938 33.42092, -96.87321 32.431...
# 1  POLYGON ((-96.84938 33.42092, -96.87321 32.431...
# 2  POLYGON ((-97.91284 34.33683, -97.92531 33.346...
# 3  POLYGON ((-97.0579 33.42436, -97.31949 32.4379...
# 4  POLYGON ((-97.06177 33.42442, -97.32332 32.437...
# 5  POLYGON ((-96.84938 33.42092, -96.87321 32.431...
# 6  POLYGON ((-96.81576 34.32217, -97.08134 33.336...
# 7  POLYGON ((-96.82664 34.32236, -96.85153 33.333...
# 8  POLYGON ((-97.05919 33.42438, -97.32056 32.437...
# 9  POLYGON ((-96.81576 34.32217, -96.8278 34.2776...
#
#                     created     platform constellation instruments  \
# 0  2023-08-20T04:40:37.325Z  sentinel-2b    sentinel-2       [msi]
# 1  2023-08-05T04:59:04.872Z  sentinel-2a    sentinel-2       [msi]
# 2  2023-08-18T06:10:25.042Z  sentinel-2a    sentinel-2       [msi]
# 3  2023-08-20T04:36:25.463Z  sentinel-2b    sentinel-2       [msi]
# 4  2023-08-15T04:07:22.379Z  sentinel-2a    sentinel-2       [msi]
# 5  2023-08-15T04:10:46.325Z  sentinel-2a    sentinel-2       [msi]
# 6  2023-08-20T04:30:59.255Z  sentinel-2b    sentinel-2       [msi]
# 7  2023-08-18T06:09:55.100Z  sentinel-2a    sentinel-2       [msi]
# 8  2023-08-05T04:52:48.750Z  sentinel-2a    sentinel-2       [msi]
# 9  2023-08-20T04:44:38.807Z  sentinel-2b    sentinel-2       [msi]
#
#    eo:cloud_cover  mgrs:utm_zone mgrs:latitude_band mgrs:grid_square  \
# 0        0.004539             14                  S               QB
# 1        0.005262             14                  S               QB
# 2        0.006437             14                  S               PC
# 3        0.009056             14                  S               PB
# 4        0.014211             14                  S               PB
# 5        0.014575             14                  S               QB
# 6        0.017386             14                  S               PC
# 7        0.040440             14                  S               QC
# 8        0.059570             14                  S               PB
# 9        0.076934             14                  S               QC
#
#     grid:code  ...                                      s2:granule_id  \
# 0  MGRS-14SQB  ...  S2B_OPER_MSI_L2A_TL_2BPS_20230819T223356_A0337...
# 1  MGRS-14SQB  ...  S2A_OPER_MSI_L2A_TL_2APS_20230804T235402_A0423...
# 2  MGRS-14SPC  ...  S2A_OPER_MSI_L2A_TL_2APS_20230818T002256_A0425...
# 3  MGRS-14SPB  ...  S2B_OPER_MSI_L2A_TL_2BPS_20230819T223356_A0337...
# 4  MGRS-14SPB  ...  S2A_OPER_MSI_L2A_TL_2APS_20230815T002553_A0425...
# 5  MGRS-14SQB  ...  S2A_OPER_MSI_L2A_TL_2APS_20230815T002553_A0425...
# 6  MGRS-14SPC  ...  S2B_OPER_MSI_L2A_TL_2BPS_20230819T223356_A0337...
# 7  MGRS-14SQC  ...  S2A_OPER_MSI_L2A_TL_2APS_20230818T002256_A0425...
# 8  MGRS-14SPB  ...  S2A_OPER_MSI_L2A_TL_2APS_20230804T235402_A0423...
# 9  MGRS-14SQC  ...  S2B_OPER_MSI_L2A_TL_2BPS_20230819T223356_A0337...
#
#    s2:reflectance_conversion_factor                     datetime  s2:sequence  \
# 0                          0.975198  2023-08-19T17:14:46.266000Z            0
# 1                          0.970632  2023-08-04T17:14:46.231000Z            0
# 2                          0.974489  2023-08-17T17:24:31.907000Z            0
# 3                          0.975198  2023-08-19T17:14:49.046000Z            0
# 4                          0.973476  2023-08-14T17:14:49.390000Z            0
# 5                          0.973476  2023-08-14T17:14:46.612000Z            0
# 6                          0.975198  2023-08-19T17:14:35.561000Z            0
# 7                          0.974489  2023-08-17T17:24:28.416000Z            0
# 8                          0.970632  2023-08-04T17:14:49.014000Z            0
# 9                          0.975198  2023-08-19T17:14:31.780000Z            0
#
#                                  earthsearch:s3_path  \
# 0  s3://sentinel-cogs/sentinel-s2-l2a-cogs/14/S/Q...
# 1  s3://sentinel-cogs/sentinel-s2-l2a-cogs/14/S/Q...
# 2  s3://sentinel-cogs/sentinel-s2-l2a-cogs/14/S/P...
# 3  s3://sentinel-cogs/sentinel-s2-l2a-cogs/14/S/P...
# 4  s3://sentinel-cogs/sentinel-s2-l2a-cogs/14/S/P...
# 5  s3://sentinel-cogs/sentinel-s2-l2a-cogs/14/S/Q...
# 6  s3://sentinel-cogs/sentinel-s2-l2a-cogs/14/S/P...
# 7  s3://sentinel-cogs/sentinel-s2-l2a-cogs/14/S/Q...
# 8  s3://sentinel-cogs/sentinel-s2-l2a-cogs/14/S/P...
# 9  s3://sentinel-cogs/sentinel-s2-l2a-cogs/14/S/Q...
#
#                               earthsearch:payload_id  \
# 0  roda-sentinel2/workflow-sentinel2-to-stac/a707...
# 1  roda-sentinel2/workflow-sentinel2-to-stac/73a7...
# 2  roda-sentinel2/workflow-sentinel2-to-stac/a898...
# 3  roda-sentinel2/workflow-sentinel2-to-stac/ee80...
# 4  roda-sentinel2/workflow-sentinel2-to-stac/ccee...
# 5  roda-sentinel2/workflow-sentinel2-to-stac/cac3...
# 6  roda-sentinel2/workflow-sentinel2-to-stac/741d...
# 7  roda-sentinel2/workflow-sentinel2-to-stac/c613...
# 8  roda-sentinel2/workflow-sentinel2-to-stac/a5ff...
# 9  roda-sentinel2/workflow-sentinel2-to-stac/2524...
#
#    earthsearch:boa_offset_applied             processing:software  \
# 0                            True  {'sentinel2-to-stac': '0.1.1'}
# 1                            True  {'sentinel2-to-stac': '0.1.1'}
# 2                            True  {'sentinel2-to-stac': '0.1.1'}
# 3                            True  {'sentinel2-to-stac': '0.1.1'}
# 4                            True  {'sentinel2-to-stac': '0.1.1'}
# 5                            True  {'sentinel2-to-stac': '0.1.1'}
# 6                            True  {'sentinel2-to-stac': '0.1.1'}
# 7                            True  {'sentinel2-to-stac': '0.1.1'}
# 8                            True  {'sentinel2-to-stac': '0.1.1'}
# 9                            True  {'sentinel2-to-stac': '0.1.1'}
#
#                     updated   proj:code
# 0  2023-08-20T04:40:37.325Z  EPSG:32614
# 1  2023-08-05T04:59:04.872Z  EPSG:32614
# 2  2023-08-18T06:10:25.042Z  EPSG:32614
# 3  2023-08-20T04:36:25.463Z  EPSG:32614
# 4  2023-08-15T04:07:22.379Z  EPSG:32614
# 5  2023-08-15T04:10:46.325Z  EPSG:32614
# 6  2023-08-20T04:30:59.255Z  EPSG:32614
# 7  2023-08-18T06:09:55.100Z  EPSG:32614
# 8  2023-08-05T04:52:48.750Z  EPSG:32614
# 9  2023-08-20T04:44:38.807Z  EPSG:32614
#
# [10 rows x 42 columns]

# %% [markdown]
# ## exploring and filtering search results

# %%
search_gdf.plot("mgrs:grid_square", alpha=0.25)
# Out:
# <Axes: >

# %%
search_gdf["s2:granule_id"].value_counts()
# Out:
# s2:granule_id
# S2B_OPER_MSI_L2A_TL_2BPS_20230819T223356_A033700_T14SQB_N05.09    1
# S2A_OPER_MSI_L2A_TL_2APS_20230804T235402_A042394_T14SQB_N05.09    1
# S2A_OPER_MSI_L2A_TL_2APS_20230818T002256_A042580_T14SPC_N05.09    1
# S2B_OPER_MSI_L2A_TL_2BPS_20230819T223356_A033700_T14SPB_N05.09    1
# S2A_OPER_MSI_L2A_TL_2APS_20230815T002553_A042537_T14SPB_N05.09    1
# S2A_OPER_MSI_L2A_TL_2APS_20230815T002553_A042537_T14SQB_N05.09    1
# S2B_OPER_MSI_L2A_TL_2BPS_20230819T223356_A033700_T14SPC_N05.09    1
# S2A_OPER_MSI_L2A_TL_2APS_20230818T002256_A042580_T14SQC_N05.09    1
# S2A_OPER_MSI_L2A_TL_2APS_20230804T235402_A042394_T14SPB_N05.09    1
# S2B_OPER_MSI_L2A_TL_2BPS_20230819T223356_A033700_T14SQC_N05.09    1
# Name: count, dtype: int64

# %%
search_gdf["area"] = search_gdf.geometry.area

# %%
search_gdf.sort_values("area", ascending=False, inplace=True)

# %%
search_gdf[["area"]]
# Out:
#        area
# 2  1.174444
# 9  1.172798
# 1  1.161135
# 0  1.161135
# 5  1.161135
# 7  0.620451
# 4  0.432199
# 8  0.429551
# 3  0.428386
# 6  0.213553

# %%
search_gdf.drop_duplicates("mgrs:grid_square", inplace=True)

# %%
search_gdf.iloc[0:4].plot("s2:granule_id", alpha=0.5)
# Out:
# <Axes: >

# %%
# # create a query searching for unique datastrip ids based on the above
q = {"s2:granule_id": {"in": search_gdf["s2:granule_id"].iloc[0:4].unique().tolist()}}

search_gdf2 = leafmap.stac_search(
    url=url,
    max_items=4,
    collections=[collection],
    bbox=bbox,
    datetime=time_range,
    query=q,
    get_gdf=True,
)

# %%
search_gdf2
# Out:
#                                             geometry  \
# 0  POLYGON ((-96.81576 34.32217, -96.8278 34.2776...
# 1  POLYGON ((-97.91284 34.33683, -97.92531 33.346...
# 2  POLYGON ((-97.06177 33.42442, -97.32332 32.437...
# 3  POLYGON ((-96.84938 33.42092, -96.87321 32.431...
#
#                     created     platform constellation instruments  \
# 0  2023-08-20T04:44:38.807Z  sentinel-2b    sentinel-2       [msi]
# 1  2023-08-18T06:10:25.042Z  sentinel-2a    sentinel-2       [msi]
# 2  2023-08-15T04:07:22.379Z  sentinel-2a    sentinel-2       [msi]
# 3  2023-08-05T04:59:04.872Z  sentinel-2a    sentinel-2       [msi]
#
#    eo:cloud_cover  mgrs:utm_zone mgrs:latitude_band mgrs:grid_square  \
# 0        0.076934             14                  S               QC
# 1        0.006437             14                  S               PC
# 2        0.014211             14                  S               PB
# 3        0.005262             14                  S               QB
#
#     grid:code  ...                                      s2:granule_id  \
# 0  MGRS-14SQC  ...  S2B_OPER_MSI_L2A_TL_2BPS_20230819T223356_A0337...
# 1  MGRS-14SPC  ...  S2A_OPER_MSI_L2A_TL_2APS_20230818T002256_A0425...
# 2  MGRS-14SPB  ...  S2A_OPER_MSI_L2A_TL_2APS_20230815T002553_A0425...
# 3  MGRS-14SQB  ...  S2A_OPER_MSI_L2A_TL_2APS_20230804T235402_A0423...
#
#    s2:reflectance_conversion_factor                     datetime  s2:sequence  \
# 0                          0.975198  2023-08-19T17:14:31.780000Z            0
# 1                          0.974489  2023-08-17T17:24:31.907000Z            0
# 2                          0.973476  2023-08-14T17:14:49.390000Z            0
# 3                          0.970632  2023-08-04T17:14:46.231000Z            0
#
#                                  earthsearch:s3_path  \
# 0  s3://sentinel-cogs/sentinel-s2-l2a-cogs/14/S/Q...
# 1  s3://sentinel-cogs/sentinel-s2-l2a-cogs/14/S/P...
# 2  s3://sentinel-cogs/sentinel-s2-l2a-cogs/14/S/P...
# 3  s3://sentinel-cogs/sentinel-s2-l2a-cogs/14/S/Q...
#
#                               earthsearch:payload_id  \
# 0  roda-sentinel2/workflow-sentinel2-to-stac/2524...
# 1  roda-sentinel2/workflow-sentinel2-to-stac/a898...
# 2  roda-sentinel2/workflow-sentinel2-to-stac/ccee...
# 3  roda-sentinel2/workflow-sentinel2-to-stac/73a7...
#
#    earthsearch:boa_offset_applied             processing:software  \
# 0                            True  {'sentinel2-to-stac': '0.1.1'}
# 1                            True  {'sentinel2-to-stac': '0.1.1'}
# 2                            True  {'sentinel2-to-stac': '0.1.1'}
# 3                            True  {'sentinel2-to-stac': '0.1.1'}
#
#                     updated   proj:code
# 0  2023-08-20T04:44:38.807Z  EPSG:32614
# 1  2023-08-18T06:10:25.042Z  EPSG:32614
# 2  2023-08-15T04:07:22.379Z  EPSG:32614
# 3  2023-08-05T04:59:04.872Z  EPSG:32614
#
# [4 rows x 42 columns]

# %%
search_gdf2.plot("mgrs:grid_square", alpha=0.5)
# Out:
# <Axes: >

# %% [markdown]
# ### plot to accentuate paved and non-paved divide

# %%
search_gdf2_list = leafmap.stac_search(
    url=url,
    max_items=4,
    collections=[collection],
    bbox=bbox,
    datetime=time_range,
    query=q,
    get_links=True,
)

# %%
search_gdf2_list
# Out:
# ['https://earth-search.aws.element84.com/v1/collections/sentinel-2-l2a/items/S2B_14SQC_20230819_0_L2A',
#  'https://earth-search.aws.element84.com/v1/collections/sentinel-2-l2a/items/S2A_14SPC_20230817_0_L2A',
#  'https://earth-search.aws.element84.com/v1/collections/sentinel-2-l2a/items/S2A_14SPB_20230814_0_L2A',
#  'https://earth-search.aws.element84.com/v1/collections/sentinel-2-l2a/items/S2A_14SQB_20230804_0_L2A']

# %% [markdown]
# ### download files for analysis

# %%
def get_item_json(item_url: str) -> dict:
    r = requests.get(item_url, timeout=30)
    r.raise_for_status()
    return r.json()


def get_raster_band_urls(item_url: str, bands: list | None = None) -> dict:
    """Return {band_name: cog_url} for a STAC item, no titiler dependency."""
    stac = get_item_json(item_url)
    band_urls = {
        key: asset["href"]
        for key, asset in stac["assets"].items()
        if asset["href"].startswith("http")
        and "image/tiff"
        in asset.get("type", "")  # COGs only; skips thumbnail jpg, xml metadata, jp2
    }
    if bands:
        band_urls = {b: band_urls[b] for b in bands if b in band_urls}
    return band_urls


def download_stac_layers(layers, out_dir, bands=None):
    for layer in layers:
        band_urls = get_raster_band_urls(layer, bands)
        if not band_urls:
            print(f"WARNING: no COG assets found for {layer}")
            continue
        for band, url in band_urls.items():
            out_file = f"{out_dir}/{layer.split('/')[-1]}_{band}.tif"
            leafmap.download_file(url, out_file, overwrite=False)


def get_stac_crs(item_url: str) -> int:
    """Handle both proj:epsg (projection ext v1) and proj:code (v2, e.g. 'EPSG:32614')."""
    stac = get_item_json(item_url)
    props = stac.get("properties", {})
    if "proj:epsg" in props:
        return props["proj:epsg"]
    if "proj:code" in props:
        return int(props["proj:code"].split(":")[-1])
    # some catalogs moved projection info to the asset level
    for asset in stac["assets"].values():
        if "proj:code" in asset:
            return int(asset["proj:code"].split(":")[-1])
        if "proj:epsg" in asset:
            return asset["proj:epsg"]
    raise KeyError(f"No projection metadata found on {item_url}")

# %%
stac_crs = get_stac_crs(search_gdf2_list[0])

# %%
stac_crs
# Out:
# 32614

# %%
download_stac_layers(
    search_gdf2_list,
    "../Data/stac/dallas",
)
# Out:
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/QC/2023/8/S2B_14SQC_20230819_0_L2A/AOT.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2B_14SQC_20230819_0_L2A_aot.tif
# 100%|██████████| 191k/191k [00:00<00:00, 436kB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/QC/2023/8/S2B_14SQC_20230819_0_L2A/B02.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2B_14SQC_20230819_0_L2A_blue.tif
# 100%|██████████| 211M/211M [01:44<00:00, 2.01MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/QC/2023/8/S2B_14SQC_20230819_0_L2A/B01.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2B_14SQC_20230819_0_L2A_coastal.tif
# 100%|██████████| 5.95M/5.95M [00:01<00:00, 3.16MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/QC/2023/8/S2B_14SQC_20230819_0_L2A/B03.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2B_14SQC_20230819_0_L2A_green.tif
# 100%|██████████| 215M/215M [01:31<00:00, 2.34MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/QC/2023/8/S2B_14SQC_20230819_0_L2A/B08.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2B_14SQC_20230819_0_L2A_nir.tif
# 100%|██████████| 228M/228M [02:32<00:00, 1.50MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/QC/2023/8/S2B_14SQC_20230819_0_L2A/B8A.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2B_14SQC_20230819_0_L2A_nir08.tif
# 100%|██████████| 60.8M/60.8M [00:24<00:00, 2.47MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/QC/2023/8/S2B_14SQC_20230819_0_L2A/B09.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2B_14SQC_20230819_0_L2A_nir09.tif
# 100%|██████████| 6.84M/6.84M [00:01<00:00, 3.69MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/QC/2023/8/S2B_14SQC_20230819_0_L2A/B04.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2B_14SQC_20230819_0_L2A_red.tif
# 100%|██████████| 225M/225M [00:48<00:00, 4.61MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/QC/2023/8/S2B_14SQC_20230819_0_L2A/B05.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2B_14SQC_20230819_0_L2A_rededge1.tif
# 100%|██████████| 59.3M/59.3M [00:16<00:00, 3.68MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/QC/2023/8/S2B_14SQC_20230819_0_L2A/B06.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2B_14SQC_20230819_0_L2A_rededge2.tif
# 100%|██████████| 59.4M/59.4M [00:11<00:00, 5.35MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/QC/2023/8/S2B_14SQC_20230819_0_L2A/B07.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2B_14SQC_20230819_0_L2A_rededge3.tif
# 100%|██████████| 60.6M/60.6M [00:12<00:00, 4.84MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/QC/2023/8/S2B_14SQC_20230819_0_L2A/SCL.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2B_14SQC_20230819_0_L2A_scl.tif
# 100%|██████████| 3.84M/3.84M [00:01<00:00, 3.26MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/QC/2023/8/S2B_14SQC_20230819_0_L2A/B11.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2B_14SQC_20230819_0_L2A_swir16.tif
# 100%|██████████| 61.9M/61.9M [00:25<00:00, 2.43MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/QC/2023/8/S2B_14SQC_20230819_0_L2A/B12.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2B_14SQC_20230819_0_L2A_swir22.tif
# 100%|██████████| 61.2M/61.2M [00:22<00:00, 2.74MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/QC/2023/8/S2B_14SQC_20230819_0_L2A/TCI.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2B_14SQC_20230819_0_L2A_visual.tif
# 100%|██████████| 327M/327M [02:03<00:00, 2.64MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/QC/2023/8/S2B_14SQC_20230819_0_L2A/WVP.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2B_14SQC_20230819_0_L2A_wvp.tif
# 100%|██████████| 95.9M/95.9M [00:49<00:00, 1.93MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/PC/2023/8/S2A_14SPC_20230817_0_L2A/AOT.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2A_14SPC_20230817_0_L2A_aot.tif
# 100%|██████████| 200k/200k [00:00<00:00, 337kB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/PC/2023/8/S2A_14SPC_20230817_0_L2A/B02.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2A_14SPC_20230817_0_L2A_blue.tif
# 100%|██████████| 217M/217M [01:51<00:00, 1.94MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/PC/2023/8/S2A_14SPC_20230817_0_L2A/B01.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2A_14SPC_20230817_0_L2A_coastal.tif
# 100%|██████████| 6.08M/6.08M [00:02<00:00, 2.92MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/PC/2023/8/S2A_14SPC_20230817_0_L2A/B03.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2A_14SPC_20230817_0_L2A_green.tif
# 100%|██████████| 219M/219M [00:56<00:00, 3.90MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/PC/2023/8/S2A_14SPC_20230817_0_L2A/B08.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2A_14SPC_20230817_0_L2A_nir.tif
# 100%|██████████| 226M/226M [00:43<00:00, 5.22MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/PC/2023/8/S2A_14SPC_20230817_0_L2A/B8A.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2A_14SPC_20230817_0_L2A_nir08.tif
# 100%|██████████| 60.4M/60.4M [00:15<00:00, 3.85MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/PC/2023/8/S2A_14SPC_20230817_0_L2A/B09.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2A_14SPC_20230817_0_L2A_nir09.tif
# 100%|██████████| 6.78M/6.78M [00:01<00:00, 3.49MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/PC/2023/8/S2A_14SPC_20230817_0_L2A/B04.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2A_14SPC_20230817_0_L2A_red.tif
# 100%|██████████| 228M/228M [00:51<00:00, 4.41MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/PC/2023/8/S2A_14SPC_20230817_0_L2A/B05.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2A_14SPC_20230817_0_L2A_rededge1.tif
# 100%|██████████| 60.0M/60.0M [00:11<00:00, 5.15MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/PC/2023/8/S2A_14SPC_20230817_0_L2A/B06.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2A_14SPC_20230817_0_L2A_rededge2.tif
# 100%|██████████| 59.6M/59.6M [00:11<00:00, 5.06MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/PC/2023/8/S2A_14SPC_20230817_0_L2A/B07.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2A_14SPC_20230817_0_L2A_rededge3.tif
# 100%|██████████| 60.2M/60.2M [00:14<00:00, 4.10MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/PC/2023/8/S2A_14SPC_20230817_0_L2A/SCL.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2A_14SPC_20230817_0_L2A_scl.tif
# 100%|██████████| 4.26M/4.26M [00:01<00:00, 2.79MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/PC/2023/8/S2A_14SPC_20230817_0_L2A/B11.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2A_14SPC_20230817_0_L2A_swir16.tif
# 100%|██████████| 62.0M/62.0M [00:08<00:00, 6.90MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/PC/2023/8/S2A_14SPC_20230817_0_L2A/B12.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2A_14SPC_20230817_0_L2A_swir22.tif
# 100%|██████████| 61.5M/61.5M [00:37<00:00, 1.62MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/PC/2023/8/S2A_14SPC_20230817_0_L2A/TCI.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2A_14SPC_20230817_0_L2A_visual.tif
# 100%|██████████| 340M/340M [01:11<00:00, 4.75MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/PC/2023/8/S2A_14SPC_20230817_0_L2A/WVP.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2A_14SPC_20230817_0_L2A_wvp.tif
# 100%|██████████| 95.8M/95.8M [00:19<00:00, 4.93MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/PB/2023/8/S2A_14SPB_20230814_0_L2A/AOT.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2A_14SPB_20230814_0_L2A_aot.tif
# 100%|██████████| 111k/111k [00:00<00:00, 593kB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/PB/2023/8/S2A_14SPB_20230814_0_L2A/B02.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2A_14SPB_20230814_0_L2A_blue.tif
# 100%|██████████| 89.4M/89.4M [00:18<00:00, 4.79MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/PB/2023/8/S2A_14SPB_20230814_0_L2A/B01.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2A_14SPB_20230814_0_L2A_coastal.tif
# 100%|██████████| 2.52M/2.52M [00:00<00:00, 2.82MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/PB/2023/8/S2A_14SPB_20230814_0_L2A/B03.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2A_14SPB_20230814_0_L2A_green.tif
# 100%|██████████| 88.8M/88.8M [00:18<00:00, 4.68MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/PB/2023/8/S2A_14SPB_20230814_0_L2A/B08.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2A_14SPB_20230814_0_L2A_nir.tif
# 100%|██████████| 87.4M/87.4M [00:18<00:00, 4.79MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/PB/2023/8/S2A_14SPB_20230814_0_L2A/B8A.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2A_14SPB_20230814_0_L2A_nir08.tif
# 100%|██████████| 23.6M/23.6M [00:06<00:00, 3.67MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/PB/2023/8/S2A_14SPB_20230814_0_L2A/B09.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2A_14SPB_20230814_0_L2A_nir09.tif
# 100%|██████████| 2.65M/2.65M [00:00<00:00, 2.75MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/PB/2023/8/S2A_14SPB_20230814_0_L2A/B04.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2A_14SPB_20230814_0_L2A_red.tif
# 100%|██████████| 90.4M/90.4M [00:20<00:00, 4.33MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/PB/2023/8/S2A_14SPB_20230814_0_L2A/B05.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2A_14SPB_20230814_0_L2A_rededge1.tif
# 100%|██████████| 23.6M/23.6M [00:03<00:00, 6.13MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/PB/2023/8/S2A_14SPB_20230814_0_L2A/B06.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2A_14SPB_20230814_0_L2A_rededge2.tif
# 100%|██████████| 23.4M/23.4M [00:03<00:00, 7.04MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/PB/2023/8/S2A_14SPB_20230814_0_L2A/B07.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2A_14SPB_20230814_0_L2A_rededge3.tif
# 100%|██████████| 23.5M/23.5M [00:04<00:00, 5.56MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/PB/2023/8/S2A_14SPB_20230814_0_L2A/SCL.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2A_14SPB_20230814_0_L2A_scl.tif
# 100%|██████████| 1.82M/1.82M [00:00<00:00, 3.02MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/PB/2023/8/S2A_14SPB_20230814_0_L2A/B11.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2A_14SPB_20230814_0_L2A_swir16.tif
# 100%|██████████| 23.6M/23.6M [00:22<00:00, 1.03MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/PB/2023/8/S2A_14SPB_20230814_0_L2A/B12.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2A_14SPB_20230814_0_L2A_swir22.tif
# 100%|██████████| 23.5M/23.5M [00:08<00:00, 2.85MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/PB/2023/8/S2A_14SPB_20230814_0_L2A/TCI.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2A_14SPB_20230814_0_L2A_visual.tif
# 100%|██████████| 144M/144M [00:22<00:00, 6.39MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/PB/2023/8/S2A_14SPB_20230814_0_L2A/WVP.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2A_14SPB_20230814_0_L2A_wvp.tif
# 100%|██████████| 37.4M/37.4M [00:06<00:00, 5.80MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/QB/2023/8/S2A_14SQB_20230804_0_L2A/AOT.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2A_14SQB_20230804_0_L2A_aot.tif
# 100%|██████████| 191k/191k [00:00<00:00, 610kB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/QB/2023/8/S2A_14SQB_20230804_0_L2A/B02.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2A_14SQB_20230804_0_L2A_blue.tif
# 100%|██████████| 223M/223M [00:50<00:00, 4.39MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/QB/2023/8/S2A_14SQB_20230804_0_L2A/B01.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2A_14SQB_20230804_0_L2A_coastal.tif
# 100%|██████████| 6.27M/6.27M [00:01<00:00, 3.94MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/QB/2023/8/S2A_14SQB_20230804_0_L2A/B03.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2A_14SQB_20230804_0_L2A_green.tif
# 100%|██████████| 224M/224M [00:35<00:00, 6.23MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/QB/2023/8/S2A_14SQB_20230804_0_L2A/B08.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2A_14SQB_20230804_0_L2A_nir.tif
# 100%|██████████| 243M/243M [00:39<00:00, 6.16MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/QB/2023/8/S2A_14SQB_20230804_0_L2A/B8A.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2A_14SQB_20230804_0_L2A_nir08.tif
# 100%|██████████| 61.8M/61.8M [00:11<00:00, 5.61MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/QB/2023/8/S2A_14SQB_20230804_0_L2A/B09.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2A_14SQB_20230804_0_L2A_nir09.tif
# 100%|██████████| 6.92M/6.92M [00:01<00:00, 3.56MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/QB/2023/8/S2A_14SQB_20230804_0_L2A/B04.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2A_14SQB_20230804_0_L2A_red.tif
# 100%|██████████| 232M/232M [00:46<00:00, 4.97MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/QB/2023/8/S2A_14SQB_20230804_0_L2A/B05.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2A_14SQB_20230804_0_L2A_rededge1.tif
# 100%|██████████| 60.6M/60.6M [00:17<00:00, 3.38MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/QB/2023/8/S2A_14SQB_20230804_0_L2A/B06.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2A_14SQB_20230804_0_L2A_rededge2.tif
# 100%|██████████| 60.9M/60.9M [00:11<00:00, 5.52MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/QB/2023/8/S2A_14SQB_20230804_0_L2A/B07.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2A_14SQB_20230804_0_L2A_rededge3.tif
# 100%|██████████| 61.6M/61.6M [00:13<00:00, 4.73MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/QB/2023/8/S2A_14SQB_20230804_0_L2A/SCL.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2A_14SQB_20230804_0_L2A_scl.tif
# 100%|██████████| 4.19M/4.19M [00:01<00:00, 3.76MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/QB/2023/8/S2A_14SQB_20230804_0_L2A/B11.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2A_14SQB_20230804_0_L2A_swir16.tif
# 100%|██████████| 62.1M/62.1M [00:14<00:00, 4.14MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/QB/2023/8/S2A_14SQB_20230804_0_L2A/B12.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2A_14SQB_20230804_0_L2A_swir22.tif
# 100%|██████████| 61.5M/61.5M [00:10<00:00, 5.70MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/QB/2023/8/S2A_14SQB_20230804_0_L2A/TCI.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2A_14SQB_20230804_0_L2A_visual.tif
# 100%|██████████| 351M/351M [01:04<00:00, 5.49MB/s]
# Downloading...
# From: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/14/S/QB/2023/8/S2A_14SQB_20230804_0_L2A/WVP.tif
# To: c:\Users\aqila\OneDrive - Syracuse University\Documents\GitHub\cdp-mapping-systems-aqila\content\Data\stac\dallas\S2A_14SQB_20230804_0_L2A_wvp.tif
# 100%|██████████| 97.5M/97.5M [00:20<00:00, 4.72MB/s]

# %%
# mosaic files based on band name


def mosaic_by_band(
    dir,
    bands: list = [
        "red",
        "blue",
        "green",
        "nir",
        "coastal",
        "nir08",
        "nir09",
        "rededge1",
        "rededge2",
        "rededge3",
        "scl",
        "swir16",
        "swir22",
    ],
    crs: str = None,
):
    mosaics = {}
    for band in bands:
        files = glob.glob(f"{dir}/*{band}.tif")

        out_file = f"{dir}/mosaic_{band}_.tif"
        raster_data = [rio.open(f) for f in files]

        mosaic, out_trans = merge(raster_data)
        out_meta = raster_data[0].meta.copy()
        out_meta.update(
            {
                "driver": "GTiff",
                "height": mosaic.shape[1],
                "width": mosaic.shape[2],
                "transform": out_trans,
                "crs": f"epsg:{crs}",
            }
        )

        with rio.open(out_file, "w", **out_meta) as dest:
            dest.write(mosaic)

        mosaics[band] = out_file

    return mosaics

# %%
mosaic_bands_all = mosaic_by_band("../Data/stac/dallas", crs=stac_crs)

# %%
mosaic_bands_all
# Out:
# {'red': '../Data/stac/dallas/mosaic_red_.tif',
#  'blue': '../Data/stac/dallas/mosaic_blue_.tif',
#  'green': '../Data/stac/dallas/mosaic_green_.tif',
#  'nir': '../Data/stac/dallas/mosaic_nir_.tif',
#  'coastal': '../Data/stac/dallas/mosaic_coastal_.tif',
#  'nir08': '../Data/stac/dallas/mosaic_nir08_.tif',
#  'nir09': '../Data/stac/dallas/mosaic_nir09_.tif',
#  'rededge1': '../Data/stac/dallas/mosaic_rededge1_.tif',
#  'rededge2': '../Data/stac/dallas/mosaic_rededge2_.tif',
#  'rededge3': '../Data/stac/dallas/mosaic_rededge3_.tif',
#  'scl': '../Data/stac/dallas/mosaic_scl_.tif',
#  'swir16': '../Data/stac/dallas/mosaic_swir16_.tif',
#  'swir22': '../Data/stac/dallas/mosaic_swir22_.tif'}

# %%
nir = rio.open(mosaic_bands_all["nir"]).read(1).astype("float32")
red = rio.open(mosaic_bands_all["red"]).read(1).astype("float32")

# %% [markdown]
# ### calculate NDVI

# %%
ndvi = (nir - red) / (nir + red)

# %%
# fill nan with -2, outside of the range but not so far outside
ndvi[np.isnan(ndvi)] = -1.1

# %%
ndvi
# Out:
# array([[ 0.32408434,  0.29939127,  0.29359823, ...,  0.73136204,
#          0.7670886 ,  0.78903455],
#        [ 0.30212304,  0.2733051 ,  0.2877433 , ...,  0.76618594,
#          0.78105634,  0.79848444],
#        [ 0.3       ,  0.26897264,  0.30549684, ...,  0.7636706 ,
#          0.79545456,  0.79603904],
#        ...,
#        [-1.1       , -1.1       , -1.1       , ...,  0.3897992 ,
#          0.37364912,  0.35989258],
#        [-1.1       , -1.1       , -1.1       , ...,  0.3893967 ,
#          0.38545954,  0.3633688 ],
#        [-1.1       , -1.1       , -1.1       , ...,  0.38307095,
#          0.39466423,  0.37937558]], shape=(20982, 20976), dtype=float32)

# %%
ndvi_mult = ndvi * 10  # to be able to visualize more easily

# %%
ndvi_mult
# Out:
# array([[  3.2408433,   2.9939127,   2.9359822, ...,   7.3136206,
#           7.670886 ,   7.8903456],
#        [  3.0212305,   2.7330508,   2.877433 , ...,   7.6618595,
#           7.8105636,   7.984844 ],
#        [  3.       ,   2.6897264,   3.0549684, ...,   7.6367064,
#           7.9545455,   7.9603906],
#        ...,
#        [-11.       , -11.       , -11.       , ...,   3.8979921,
#           3.7364912,   3.5989258],
#        [-11.       , -11.       , -11.       , ...,   3.893967 ,
#           3.8545954,   3.633688 ],
#        [-11.       , -11.       , -11.       , ...,   3.8307095,
#           3.9466424,   3.7937558]], shape=(20982, 20976), dtype=float32)

# %%
ndvi_image = leafmap.array_to_image(ndvi, source=mosaic_bands_all["nir"])

# %%
ndvi_multi_image = leafmap.array_to_image(ndvi_mult, source=mosaic_bands_all["nir"])

# %%
m = leafmap.Map()
m.add_raster(ndvi_multi_image, layer_name="NDVI", vmin=-10, vmax=10, cmap="PiYG")
m
# Out:
# Map(center=[33.371449, -96.78545], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title',…

# %%
# get histogram of ndvi image values
plt.hist(ndvi[ndvi != -1.1].ravel(), bins=100, color="red", alpha=0.7)
# Out:
# (array([7.3600000e+02, 1.0900000e+02, 1.9400000e+02, 1.5300000e+02,
#         1.8900000e+02, 2.4900000e+02, 2.6000000e+02, 2.6200000e+02,
#         3.2300000e+02, 3.7200000e+02, 4.4100000e+02, 5.3400000e+02,
#         5.4100000e+02, 5.8900000e+02, 6.8800000e+02, 7.7300000e+02,
#         8.0800000e+02, 8.5600000e+02, 9.5400000e+02, 1.2790000e+03,
#         1.9910000e+03, 2.9050000e+03, 3.3610000e+03, 5.2290000e+03,
#         8.6750000e+03, 1.1845000e+04, 1.5470000e+04, 2.6985000e+04,
#         4.7393000e+04, 6.2491000e+04, 8.5083000e+04, 1.2240300e+05,
#         1.6801800e+05, 2.2831800e+05, 3.2449200e+05, 4.1876100e+05,
#         4.5945500e+05, 5.4559400e+05, 6.9949500e+05, 9.0689300e+05,
#         1.0906650e+06, 1.1336000e+06, 1.0061570e+06, 9.1770500e+05,
#         9.1282000e+05, 8.1091700e+05, 6.2049700e+05, 4.9112800e+05,
#         5.1702000e+05, 9.4768500e+05, 1.3398390e+06, 1.6424740e+06,
#         1.7790490e+06, 1.8359400e+06, 1.8716200e+06, 2.1360520e+06,
#         2.9058940e+06, 4.4808210e+06, 5.9261890e+06, 7.1391380e+06,
#         8.4161050e+06, 9.5363410e+06, 1.0395959e+07, 1.1032095e+07,
#         1.1479734e+07, 1.1864555e+07, 1.2119759e+07, 1.2279935e+07,
#         1.2302444e+07, 1.2240677e+07, 1.2133516e+07, 1.1922694e+07,
#         1.1610283e+07, 1.1221036e+07, 1.0735667e+07, 1.0199962e+07,
#         9.6640520e+06, 9.1397960e+06, 8.6400040e+06, 8.1783140e+06,
#         7.8333330e+06, 7.5431030e+06, 7.3643210e+06, 7.2867060e+06,
#         7.2914000e+06, 7.4616170e+06, 7.7802640e+06, 8.3999030e+06,
#         9.4010320e+06, 1.0808060e+07, 1.2063712e+07, 1.1031922e+07,
#         6.5181920e+06, 2.3013390e+06, 3.9920300e+05, 1.6173000e+04,
#         8.5000000e+01, 2.2000000e+01, 2.0000000e+01, 7.2000000e+01]),
#  array([-0.996997  , -0.97703236, -0.95706767, -0.93710303, -0.91713834,
#         -0.8971737 , -0.87720901, -0.85724437, -0.83727968, -0.81731504,
#         -0.79735041, -0.77738571, -0.75742108, -0.73745644, -0.71749175,
#         -0.69752705, -0.67756242, -0.65759778, -0.63763309, -0.61766839,
#         -0.59770375, -0.57773912, -0.55777442, -0.53780979, -0.51784515,
#         -0.49788046, -0.47791582, -0.45795113, -0.43798649, -0.4180218 ,
#         -0.39805716, -0.37809247, -0.35812783, -0.3381632 , -0.3181985 ,
#         -0.29823387, -0.27826917, -0.25830454, -0.23833984, -0.21837521,
#         -0.19841051, -0.17844588, -0.15848124, -0.13851655, -0.11855191,
#         -0.09858721, -0.07862258, -0.05865788, -0.03869325, -0.01872861,
#          0.00123608,  0.02120078,  0.04116535,  0.06113005,  0.08109474,
#          0.10105944,  0.12102401,  0.14098871,  0.1609534 ,  0.18091798,
#          0.20088267,  0.22084737,  0.24081206,  0.26077664,  0.28074133,
#          0.30070603,  0.3206706 ,  0.3406353 ,  0.36059999,  0.38056469,
#          0.40052927,  0.42049396,  0.44045866,  0.46042323,  0.48038793,
#          0.50035262,  0.52031732,  0.54028189,  0.56024659,  0.58021128,
#          0.60017598,  0.62014055,  0.64010525,  0.66006994,  0.68003452,
#          0.69999921,  0.71996391,  0.7399286 ,  0.75989318,  0.77985787,
#          0.79982257,  0.81978714,  0.83975184,  0.85971653,  0.87968123,
#          0.89964581,  0.9196105 ,  0.9395752 ,  0.95953977,  0.97950447,
#          0.99946922]),
#  <BarContainer object of 100 artists>)

# %%
def categorize_np_array(array):

    cat_array = np.zeros(array.shape)
    cat_array[array < 1] = 5
    cat_array[array < 0.8] = 4
    cat_array[array < 0.6] = 3
    cat_array[array < 0.4] = 2
    cat_array[array < 0.2] = 1

    return cat_array

# %%
cat_ndvi = categorize_np_array(ndvi)

# %%
cat_ndvi
# Out:
# array([[2., 2., 2., ..., 4., 4., 4.],
#        [2., 2., 2., ..., 4., 4., 4.],
#        [2., 2., 2., ..., 4., 4., 4.],
#        ...,
#        [1., 1., 1., ..., 2., 2., 2.],
#        [1., 1., 1., ..., 2., 2., 2.],
#        [1., 1., 1., ..., 2., 2., 2.]], shape=(20982, 20976))

# %%
ndvi_image_cat = leafmap.array_to_image(cat_ndvi, source=mosaic_bands_all["nir"])

# %%
m = leafmap.Map()
m.add_raster(
    ndvi_image_cat, layer_name="NDVI", vmin=1, vmax=5, cmap="Set1", draw_control=False
)
m.add_colormap(
    "Set1",
    label="ndvi",
    width=8.0,
    height=0.4,
    orientation="horizontal",
    vmin=1,
    vmax=5,
)

m
# Out:
# Map(center=[33.371449, -96.78545], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title',…

# %% [markdown]
# ## k-means

# %%
def resample_raster(in_file, out_file, upscale_factor=0.5):
    with rio.open(in_file) as dataset:

        # resample data to target shape
        data = dataset.read(
            out_shape=(
                dataset.count,
                int(dataset.height * upscale_factor),
                int(dataset.width * upscale_factor),
            ),
            resampling=rio.enums.Resampling.bilinear,
        )

        # scale image transform
        transform = dataset.transform * dataset.transform.scale(
            (dataset.width / data.shape[-1]), (dataset.height / data.shape[-2])
        )

        # update metadata
        meta = dataset.meta.copy()
        meta.update(
            {
                "height": data.shape[1],
                "width": data.shape[2],
                "transform": transform,
            }
        )

        with rio.open(out_file, "w", **meta) as dst:
            dst.write(data)

# %%
for band in mosaic_bands_all.keys():
    print(band, rio.open(mosaic_bands_all[band]).read(1).shape)
# Out:
# red (20982, 20976)
# blue (20982, 20976)
# green (20982, 20976)
# nir (20982, 20976)
# coastal (3497, 3496)
# nir08 (10491, 10488)
# nir09 (3497, 3496)
# rededge1 (10491, 10488)
# rededge2 (10491, 10488)
# rededge3 (10491, 10488)
# scl (10491, 10488)
# swir16 (10491, 10488)
# swir22 (10491, 10488)

# %%
# set resampling ratio for each band- note that some are higher resolution than others and need a different scaling factor
bands_to_resample = {
    "red": 0.25,
    "blue": 0.25,
    "green": 0.25,
    "nir": 0.25,
    "nir08": 0.5,
    "rededge1": 0.5,
    "rededge2": 0.5,
    "rededge3": 0.5,
    "scl": 0.5,
    "swir16": 0.5,
    "swir22": 0.5,
}

# %%
# resample the bands so they are all smaller and uniform
for band, ratio in bands_to_resample.items():
    resample_raster(
        mosaic_bands_all[band], f"../Data/stac/dallas/upscaled_{band}.tif", ratio
    )
    mosaic_bands_all[f"{band}"] = f"../Data/stac/dallas/upscaled_{band}.tif"

# %%
mosaic_bands_all
# Out:
# {'red': '../Data/stac/dallas/upscaled_red.tif',
#  'blue': '../Data/stac/dallas/upscaled_blue.tif',
#  'green': '../Data/stac/dallas/upscaled_green.tif',
#  'nir': '../Data/stac/dallas/upscaled_nir.tif',
#  'coastal': '../Data/stac/dallas/mosaic_coastal_.tif',
#  'nir08': '../Data/stac/dallas/upscaled_nir08.tif',
#  'nir09': '../Data/stac/dallas/mosaic_nir09_.tif',
#  'rededge1': '../Data/stac/dallas/upscaled_rededge1.tif',
#  'rededge2': '../Data/stac/dallas/upscaled_rededge2.tif',
#  'rededge3': '../Data/stac/dallas/upscaled_rededge3.tif',
#  'scl': '../Data/stac/dallas/upscaled_scl.tif',
#  'swir16': '../Data/stac/dallas/upscaled_swir16.tif',
#  'swir22': '../Data/stac/dallas/upscaled_swir22.tif'}

# %%
# create a new dict with all bands excpct coastal
mosaic_bands_all_no_coastal = {
    k: v for k, v in mosaic_bands_all.items() if k not in ["coastal", "nir09"]
}

# %%
mosaic_bands_all_no_coastal
# Out:
# {'red': '../Data/stac/dallas/upscaled_red.tif',
#  'blue': '../Data/stac/dallas/upscaled_blue.tif',
#  'green': '../Data/stac/dallas/upscaled_green.tif',
#  'nir': '../Data/stac/dallas/upscaled_nir.tif',
#  'nir08': '../Data/stac/dallas/upscaled_nir08.tif',
#  'rededge1': '../Data/stac/dallas/upscaled_rededge1.tif',
#  'rededge2': '../Data/stac/dallas/upscaled_rededge2.tif',
#  'rededge3': '../Data/stac/dallas/upscaled_rededge3.tif',
#  'scl': '../Data/stac/dallas/upscaled_scl.tif',
#  'swir16': '../Data/stac/dallas/upscaled_swir16.tif',
#  'swir22': '../Data/stac/dallas/upscaled_swir22.tif'}

# %%
mosaic_bands_all_no_coastal_cols = mosaic_bands_all_no_coastal.keys()

# %%
for band in mosaic_bands_all_no_coastal.keys():
    print(band, rio.open(mosaic_bands_all_no_coastal[band]).read(1).shape)

mosaic_bands_all_no_coastal = np.stack(
    [
        rio.open(mosaic_bands_all_no_coastal[band]).read(1)
        for band in mosaic_bands_all_no_coastal.keys()
    ],
    axis=-1,
)
# Out:
# red (5245, 5244)
# blue (5245, 5244)
# green (5245, 5244)
# nir (5245, 5244)
# nir08 (5245, 5244)
# rededge1 (5245, 5244)
# rededge2 (5245, 5244)
# rededge3 (5245, 5244)
# scl (5245, 5244)
# swir16 (5245, 5244)
# swir22 (5245, 5244)

# %%
reshaped_img = reshape_as_image(mosaic_bands_all_no_coastal)

# %%
reshaped_img.shape
# Out:
# (5244, 11, 5245)

# %%
mosaic_bands_all_no_coastal.shape
# Out:
# (5245, 5244, 11)

# %%
rows, cols, bands = mosaic_bands_all_no_coastal.shape

k = 10  # num of clusters

kmeans_predictions = KMeans(n_clusters=k, random_state=0).fit(
    mosaic_bands_all_no_coastal.reshape(rows * cols, bands)
)

kmeans_predictions_2d = kmeans_predictions.labels_.reshape(rows, cols)

# %%
kmeans_predictions_2d
# Out:
# array([[4, 7, 7, ..., 8, 8, 5],
#        [4, 7, 7, ..., 8, 8, 8],
#        [1, 6, 6, ..., 8, 8, 5],
#        ...,
#        [2, 2, 2, ..., 7, 7, 7],
#        [2, 2, 2, ..., 7, 7, 7],
#        [2, 2, 2, ..., 7, 7, 7]], shape=(5245, 5244), dtype=int32)

# %%
# plot prediction results

m = leafmap.Map()
m.add_raster(
    leafmap.array_to_image(
        kmeans_predictions_2d,
        source=mosaic_bands_all["red"],
    ),
    layer_name="KMeans",
    colormap="Set1",
    draw_control=False,
    vmin=0,
    vmax=9,
)

# add a legend
m.add_colormap(
    "Set1",
    label="KMeans",
    width=8.0,
    height=0.4,
    orientation="horizontal",
    vmin=0,
    vmax=9,
)

m
# Out:
# Map(center=[33.371449, -96.78545], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title',…
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\aqila\anaconda3\envs\cdp\Lib\site-packages\ipywidgets\widgets\widget.py:222, in _show_traceback.<locals>.m(self, *args, **kwargs)
#     220 def m(self, *args, **kwargs):
#     221     try:
# --> 222         return(method(self, *args, **kwargs))
#     223     except Exception as e:
#     224         ip = get_ipython()
#
# File c:\Users\aqila\anaconda3\envs\cdp\Lib\site-packages\ipywidgets\widgets\widget.py:773, in Widget._handle_msg(self, msg)
#     771         if 'buffer_paths' in data:
#     772             _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 773         self.set_state(state)
#     775 # Handle a state request.
#     776 elif method == 'request_state':
#
# File c:\Users\aqila\anaconda3\envs\cdp\Lib\site-packages\ipywidgets\widgets\widget.py:650, in Widget.set_state(self, sync_data)
#     645         self._send(msg, buffers=echo_buffers)
#     647 # The order of these context managers is important. Properties must
#     648 # be locked when the hold_trait_notification context manager is
#     649 # released and notifications are fired.
# --> 650 with self._lock_property(**sync_data), self.hold_trait_notifications():
#     651     for name in sync_data:
#     652         if name in self.keys:
#
# File c:\Users\aqila\anaconda3\envs\cdp\Lib\contextlib.py:148, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     146 if typ is None:
#     147     try:
# --> 148         next(self.gen)
#     149     except StopIteration:
#     150         return False
#
# File c:\Users\aqila\anaconda3\envs\cdp\Lib\site-packages\traitlets\traitlets.py:1510, in HasTraits.hold_trait_notifications(self)
#    1508 for changes in cache.values():
#    1509     for change in changes:
# -> 1510         self.notify_change(change)
#
# File c:\Users\aqila\anaconda3\envs\cdp\Lib\site-packages\ipywidgets\widgets\widget.py:701, in Widget.notify_change(self, change)
#     698     if name in self.keys and self._should_send_property(name, getattr(self, name)):
#     699         # Send new state to front-end
#     700         self.send_state(key=name)
# --> 701 super().notify_change(change)
#
# File c:\Users\aqila\anaconda3\envs\cdp\Lib\site-packages\traitlets\traitlets.py:1525, in HasTraits.notify_change(self, change)
#    1523 def notify_change(self, change: Bunch) -> None:
#    1524     """Notify observers of a change event"""
# -> 1525     return self._notify_observers(change)
#
# File c:\Users\aqila\anaconda3\envs\cdp\Lib\site-packages\traitlets\traitlets.py:1568, in HasTraits._notify_observers(self, event)
#    1565 elif isinstance(c, EventHandler) and c.name is not None:
#    1566     c = getattr(self, c.name)
# -> 1568 c(event)
#
# File c:\Users\aqila\anaconda3\envs\cdp\Lib\site-packages\leafmap\toolbar.py:465, in main_toolbar.<locals>.tool_callback(change)
#     463     split_basemaps(m)
#     464 if tool_name == "planet":
# --> 465     split_basemaps(m, layers_dict=planet_tiles())
#     466 elif tool_name == "open_data":
#     467     open_data_widget(m)
#
# File c:\Users\aqila\anaconda3\envs\cdp\Lib\site-packages\leafmap\common.py:2365, in planet_tiles(api_key, token_name, tile_format)
#    2361         dict: A dictionary of TileLayer.
#    2362     """
#    2363
#    2364     catalog = {}
# -> 2365     quarterly = planet_quarterly_tiles(api_key, token_name, tile_format)
#    2366     monthly = planet_monthly_tiles(api_key, token_name, tile_format)
#    2367
#    2368     for key in quarterly:
#
# File c:\Users\aqila\anaconda3\envs\cdp\Lib\site-packages\leafmap\common.py:2327, in planet_quarterly_tiles(api_key, token_name, tile_format)
#    2323     if tile_format not in ["ipyleaflet", "folium"]:
#    2324         raise ValueError("The tile format must be either ipyleaflet or folium.")
#    2325
#    2326     tiles = {}
# -> 2327     links = planet_quarterly(api_key, token_name)
#    2328
#    2329     for url in links:
#    2330         index = url.find("20")
#
# File c:\Users\aqila\anaconda3\envs\cdp\Lib\site-packages\leafmap\common.py:2224, in planet_quarterly(api_key, token_name)
#    2220
#    2221     if api_key is None:
#    2222         api_key = os.environ.get(token_name)
#    2223         if api_key is None:
# -> 2224             raise ValueError("The Planet API Key must be provided.")
#    2225
#    2226     today = date.today()
#    2227     year_now = int(today.strftime("%Y"))
#
# ValueError: The Planet API Key must be provided.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\aqila\anaconda3\envs\cdp\Lib\site-packages\ipywidgets\widgets\widget.py:222, in _show_traceback.<locals>.m(self, *args, **kwargs)
#     220 def m(self, *args, **kwargs):
#     221     try:
# --> 222         return(method(self, *args, **kwargs))
#     223     except Exception as e:
#     224         ip = get_ipython()
#
# File c:\Users\aqila\anaconda3\envs\cdp\Lib\site-packages\ipywidgets\widgets\widget.py:773, in Widget._handle_msg(self, msg)
#     771         if 'buffer_paths' in data:
#     772             _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 773         self.set_state(state)
#     775 # Handle a state request.
#     776 elif method == 'request_state':
#
# File c:\Users\aqila\anaconda3\envs\cdp\Lib\site-packages\ipywidgets\widgets\widget.py:650, in Widget.set_state(self, sync_data)
#     645         self._send(msg, buffers=echo_buffers)
#     647 # The order of these context managers is important. Properties must
#     648 # be locked when the hold_trait_notification context manager is
#     649 # released and notifications are fired.
# --> 650 with self._lock_property(**sync_data), self.hold_trait_notifications():
#     651     for name in sync_data:
#     652         if name in self.keys:
#
# File c:\Users\aqila\anaconda3\envs\cdp\Lib\contextlib.py:148, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     146 if typ is None:
#     147     try:
# --> 148         next(self.gen)
#     149     except StopIteration:
#     150         return False
#
# File c:\Users\aqila\anaconda3\envs\cdp\Lib\site-packages\traitlets\traitlets.py:1510, in HasTraits.hold_trait_notifications(self)
#    1508 for changes in cache.values():
#    1509     for change in changes:
# -> 1510         self.notify_change(change)
#
# File c:\Users\aqila\anaconda3\envs\cdp\Lib\site-packages\ipywidgets\widgets\widget.py:701, in Widget.notify_change(self, change)
#     698     if name in self.keys and self._should_send_property(name, getattr(self, name)):
#     699         # Send new state to front-end
#     700         self.send_state(key=name)
# --> 701 super().notify_change(change)
#
# File c:\Users\aqila\anaconda3\envs\cdp\Lib\site-packages\traitlets\traitlets.py:1525, in HasTraits.notify_change(self, change)
#    1523 def notify_change(self, change: Bunch) -> None:
#    1524     """Notify observers of a change event"""
# -> 1525     return self._notify_observers(change)
#
# File c:\Users\aqila\anaconda3\envs\cdp\Lib\site-packages\traitlets\traitlets.py:1568, in HasTraits._notify_observers(self, event)
#    1565 elif isinstance(c, EventHandler) and c.name is not None:
#    1566     c = getattr(self, c.name)
# -> 1568 c(event)
#
# File c:\Users\aqila\anaconda3\envs\cdp\Lib\site-packages\leafmap\toolbar.py:490, in main_toolbar.<locals>.tool_callback(change)
#     488     m.add(wbt_control)
#     489 elif tool_name == "timeslider":
# --> 490     m.add_time_slider()
#     491 elif tool_name == "save_map":
#     492     save_map((m))
#
# File c:\Users\aqila\anaconda3\envs\cdp\Lib\site-packages\leafmap\leafmap.py:4613, in Map.add_time_slider(self, layers, labels, time_interval, position, slider_length, zoom_to_layer, tile_args, **kwargs)
#    4600 """Adds a time slider to the map.
#    4601
#    4602 Args:
#    (...)   4609     tile_args (dict, optional): Additional arguments to pass to the get_local_tile_layer function. Defaults to None.
#    4610 """
#    4611 from .toolbar import time_slider
# -> 4613 time_slider(
#    4614     self,
#    4615     layers,
#    4616     labels,
#    4617     time_interval,
#    4618     position,
#    4619     slider_length,
#    4620     zoom_to_layer,
#    4621     tile_args,
#    4622     **kwargs,
#    4623 )
#
# File c:\Users\aqila\anaconda3\envs\cdp\Lib\site-packages\leafmap\toolbar.py:1908, in time_slider(m, layers, labels, time_interval, position, slider_length, zoom_to_layer, tile_args, **kwargs)
#    1905     raise TypeError("The layers must be a dictionary.")
#    1907 if len(layers) == 0:
# -> 1908     layers = planet_monthly_tiles()
#    1910 if labels is None:
#    1911     labels = list(layers.keys())
#
# File c:\Users\aqila\anaconda3\envs\cdp\Lib\site-packages\leafmap\common.py:2284, in planet_monthly_tiles(api_key, token_name, tile_format)
#    2280     if tile_format not in ["ipyleaflet", "folium"]:
#    2281         raise ValueError("The tile format must be either ipyleaflet or folium.")
#    2282
#    2283     tiles = {}
# -> 2284     link = planet_monthly(api_key, token_name)
#    2285
#    2286     for url in link:
#    2287         index = url.find("20")
#
# File c:\Users\aqila\anaconda3\envs\cdp\Lib\site-packages\leafmap\common.py:2183, in planet_monthly(api_key, token_name)
#    2179
#    2180     if api_key is None:
#    2181         api_key = os.environ.get(token_name)
#    2182         if api_key is None:
# -> 2183             raise ValueError("The Planet API Key must be provided.")
#    2184
#    2185     today = date.today()
#    2186     year_now = int(today.strftime("%Y"))
#
# ValueError: The Planet API Key must be provided.

# %%
import pandas as pd

# %%
xb, yb = "red", "nir"  # two test bands
labels = kmeans_predictions_2d.reshape(-1)

df = pd.DataFrame(
    mosaic_bands_all_no_coastal.reshape(rows * cols, bands)[idx],
    columns=mosaic_bands_all_no_coastal_cols,
)
df["cluster"] = labels[idx]
print(df.columns.to_list())
g = sns.FacetGrid(
    df,
    col="cluster",
    col_wrap=4,
    height=2.6,
    aspect=1,
)


def panel(data, color, **kws):
    ax = plt.gca()
    # reference points
    ax.scatter(
        df[xb],
        df[yb],
        s=2,
        color="0.85",
        linewidth=0,
        rasterized=True,
    )

    k = data["cluster"].iloc[0]
    ax.scatter(data[xb], data[yb], s=3, color=palette[k], alpha=0.5, linewidth=0)


g.map_dataframe(panel)
g.set_axis_labels(f"{xb} (DN)", f"{yb} (DN)")
g.set_titles("cluster {col_name}")
g.figure.suptitle("NIR vs Red by cluster", y=1.03)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[84], line 5
#       1 xb, yb = "red", "nir"  # two test bands
#       2 labels = kmeans_predictions_2d.reshape(-1)
#       3
#       4 df = pd.DataFrame(
# ----> 5     mosaic_bands_all_no_coastal.reshape(rows * cols, bands)[idx],
#       6     columns=mosaic_bands_all_no_coastal_cols,
#       7 )
#       8 df["cluster"] = labels[idx]
#
# NameError: name 'idx' is not defined
