# %%
import pandas as pd
import geopandas as gpd

# %%
ntas = gpd.read_file("../Data/nyc_ntas_2020.geojson")

# %%
cb = pd.read_csv(
    "/Users/marioag/Documents/GitHub/citibike-viewer/data/od/202302-citibike-tripdata.csv"
)
# Out:
# /var/folders/g5/b592wl6x12s0tx4jfw9f7_j40000gn/T/ipykernel_37561/4078996454.py:1: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   cb = pd.read_csv(

# %%
cb.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  16991A7C313082EB   classic_bike  2023-02-16 18:20:42  2023-02-16 18:38:06
# 1  856FFB566BEEB824   classic_bike  2023-02-09 17:29:36  2023-02-09 17:33:07
# 2  B1FE28D50B493430   classic_bike  2023-02-16 15:33:51  2023-02-16 15:35:01
# 3  870EA3D724EA6162   classic_bike  2023-02-23 17:11:39  2023-02-23 17:12:56
# 4  7DE8FA9EAAE8C4ED  electric_bike  2023-02-18 19:29:17  2023-02-18 19:50:52
#
#              start_station_name start_station_id  \
# 0  Kosciuszko St & Nostrand Ave          4519.04
# 1       Riverside Dr & W 138 St          7942.21
# 2       Clinton St & Tillary St          4748.07
# 3       Clinton St & Tillary St          4748.07
# 4        Audubon Ave & W 192 St          8469.05
#
#                      end_station_name end_station_id  start_lat  start_lng  \
# 0             Eastern Pkwy & Troy Ave        3862.07  40.690698 -73.951423
# 1  St. Nicholas Terrace & Convent Ave        7937.15  40.823134 -73.955860
# 2                 Clark St & Henry St        4789.03  40.696233 -73.991421
# 3                 Clark St & Henry St        4789.03  40.696233 -73.991421
# 4  St. Nicholas Terrace & Convent Ave        7937.15  40.855890 -73.927082
#
#      end_lat    end_lng member_casual
# 0  40.669290 -73.936790        casual
# 1  40.821294 -73.947868        member
# 2  40.697601 -73.993446        member
# 3  40.697601 -73.993446        member
# 4  40.821294 -73.947868        member

# %%
cb.rename(
    columns={
        "start_station_id": "source",
        "end_station_id": "target",
    },
    inplace=True,
)

# %%
cb["lat"] = cb["start_lat"]
cb["lon"] = cb["start_lng"]

# %%
# cb.to_csv("../Data/citibike_sample.csv", index=False)

# %%
# groupby start and end stations
cb_grouped = (
    cb.groupby(["source", "target", "lat", "lon", "start_station_name"])
    .size()
    .reset_index(name="weight")
)

# %%
cb_grouped.shape
# Out:
# (834630, 6)

# %%
# cb_grouped.to_csv("../Data/citibike_grouped.csv", index=False)

# %%
# assign nta stats to stations
stations_gdf = gpd.GeoDataFrame(
    cb_grouped,
    geometry=gpd.points_from_xy(cb_grouped["lon"], cb_grouped["lat"], crs="EPSG:4326"),
)
stations_w_ntas = gpd.sjoin(stations_gdf, ntas, how="left", predicate="intersects")

# %%
# get unique stations and their coordinates
stations = (
    cb_grouped[
        [
            "source",
            "lat",
            "lon",
            "start_station_name",
        ]
    ]
    .drop_duplicates(subset=["source", "start_station_name"], keep="first")
    .rename(
        columns={
            "source": "id",
            "lat": "latitude",
            "lon": "longitude",
            "start_station_name": "name",
        }
    )
)

# %%
stations
# Out:
#              id   latitude  longitude                                name
# 0       2733.03  40.633349 -74.016569                     67 St & Erik Pl
# 37      2782.02  40.635679 -74.020005                       5 Ave & 66 St
# 95      2821.05  40.635560 -74.012980                       7 Ave & 62 St
# 145     2832.03  40.637033 -74.022141               4 Ave & Shore Road Dr
# 244     2872.02  40.637660 -74.017820                       63 St & 5 Ave
# ...         ...        ...        ...                                 ...
# 834526  8795.03  40.878016 -73.884744  Grand Concourse & E Mosholu Pkwy S
# 834540  8799.01  40.878120 -73.891920              Goulden Ave & W 205 St
# 834574  8811.01  40.880294 -73.886065             Paul Ave & Mosholu Pkwy
# 834585  8841.03  40.882178 -73.886925     W Mosholu Pkwy S & Sedgwick Ave
# 834613   SYS038  40.709540 -73.931514                Morgan Loading Docks
#
# [3564 rows x 4 columns]

# %%
stations_attr = stations.merge(
    stations_w_ntas[
        ["source", "start_station_name", "BoroName", "NTAName"]
    ].drop_duplicates(subset=["source", "start_station_name"], keep="first"),
    left_on=["id", "name"],
    right_on=["source", "start_station_name"],
    how="left",
    suffixes=("", "_nta"),
)  # .shape

# %%
stations_attr
# Out:
#            id   latitude  longitude                                name  \
# 0     2733.03  40.633349 -74.016569                     67 St & Erik Pl
# 1     2782.02  40.635679 -74.020005                       5 Ave & 66 St
# 2     2821.05  40.635560 -74.012980                       7 Ave & 62 St
# 3     2832.03  40.637033 -74.022141               4 Ave & Shore Road Dr
# 4     2872.02  40.637660 -74.017820                       63 St & 5 Ave
# ...       ...        ...        ...                                 ...
# 3559  8795.03  40.878016 -73.884744  Grand Concourse & E Mosholu Pkwy S
# 3560  8799.01  40.878120 -73.891920              Goulden Ave & W 205 St
# 3561  8811.01  40.880294 -73.886065             Paul Ave & Mosholu Pkwy
# 3562  8841.03  40.882178 -73.886925     W Mosholu Pkwy S & Sedgwick Ave
# 3563   SYS038  40.709540 -73.931514                Morgan Loading Docks
#
#        source                  start_station_name  BoroName  \
# 0     2733.03                     67 St & Erik Pl  Brooklyn
# 1     2782.02                       5 Ave & 66 St  Brooklyn
# 2     2821.05                       7 Ave & 62 St  Brooklyn
# 3     2832.03               4 Ave & Shore Road Dr  Brooklyn
# 4     2872.02                       63 St & 5 Ave  Brooklyn
# ...       ...                                 ...       ...
# 3559  8795.03  Grand Concourse & E Mosholu Pkwy S     Bronx
# 3560  8799.01              Goulden Ave & W 205 St     Bronx
# 3561  8811.01             Paul Ave & Mosholu Pkwy     Bronx
# 3562  8841.03     W Mosholu Pkwy S & Sedgwick Ave     Bronx
# 3563   SYS038                Morgan Loading Docks  Brooklyn
#
#                     NTAName
# 0                 Bay Ridge
# 1                 Bay Ridge
# 2     Sunset Park (Central)
# 3                 Bay Ridge
# 4     Sunset Park (Central)
# ...                     ...
# 3559           Bedford Park
# 3560           Bedford Park
# 3561           Bedford Park
# 3562           Bedford Park
# 3563      East Williamsburg
#
# [3564 rows x 8 columns]

# %%
stations_attr.to_csv("../Data/citibike_stations_attr.csv", index=False)
